# %%
import pandas as pd
import numpy as np

import datetime as dt

from dateutil.relativedelta import relativedelta


import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv("/content/Content.csv")
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %%
content = pd.read_csv("/content/Content.csv")

# %%
content.dtypes
# Out:
# Unnamed: 0     int64
# Content ID    object
# User ID       object
# Type          object
# Category      object
# URL           object
# dtype: object

# %%
content.dropna(how='all')
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %%
content.rename(columns = {'Type':'Content_Type'}, inplace = True)

# %%
content.head(3)
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
#
#                                 User ID Content_Type        Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo        Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43        photo  healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4        photo  healthy eating
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  https://socialbuzz.cdn.com/content/storage/230...

# %%
pd.read_csv("/content/ReactionTypes.csv")
# Out:
#     Unnamed: 0         Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %%
reaction_types = pd.read_csv("/content/ReactionTypes.csv")

# %%
pd.read_csv("/content/Reactions.csv")
# Out:
#        Unnamed: 0                            Content ID  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 0                                       NaN         NaN  2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# ...

# %%
reactions= pd.read_csv("/content/Reactions.csv")

# %%
reactions.dropna()
# Out:
#        Unnamed: 0                            Content ID  \
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5               5  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25547       25547  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# ...

# %%
reactions.head(3)
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID     Type             Datetime
# 0                                   NaN      NaN  2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike  2021-06-17 12:22:51

# %% [markdown]
# merge the dataframes with reactions as the main

# %%
reactions.merge(content,how='inner',on="Content ID")
# Out:
#        Unnamed: 0_x                            Content ID  \
# 0                 0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1                 1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2                 2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3                 3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4                 4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...             ...                                   ...
# 25548         25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549         25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550         25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551         25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552         25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID_x        Type             Datetime  \
# 0                                       NaN         NaN  2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# ...

# %%
reaction_content_df=reactions.merge(content,how='inner',on ="Content ID")

# %%
reaction_content_df.head(3)
# Out:
#    Unnamed: 0_x                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2             2  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                               User ID_x     Type             Datetime  \
# 0                                   NaN      NaN  2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike  2021-06-17 12:22:51
#
#    Unnamed: 0_y                             User ID_y Content_Type  Category  \
# 0             0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying
# 1             0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying
# 2             0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo  Studying
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# ...

# %% [markdown]
# join the reaction types to the 1st join

# %%
reaction_content_df.merge(reaction_types, how ='inner')
# Out:
#        Unnamed: 0_x                            Content ID  \
# 0                 1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1                 4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2                35  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3                52  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 4                88  230c4e4d-70c3-461d-b42c-ec09396efb3f
# ...             ...                                   ...
# 24568         25489  435007a5-6261-4d8b-b0a4-55fdc189754b
# 24569         25491  435007a5-6261-4d8b-b0a4-55fdc189754b
# 24570         25512  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 24571         25524  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 24572         25531  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
#
#                                   User ID_x     Type             Datetime  \
# 0      5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 1      34e8add9-0206-47fd-a501-037b994650a2  disgust  2021-01-06 19:13:01
# ...

# %% [markdown]
# the final dataset after merging the 3tables

# %%
final_df=reaction_content_df.merge(reaction_types, how ='inner')

# %%
final_df.head()
# Out:
#    Unnamed: 0_x                            Content ID  \
# 0             1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2            35  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3            52  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 4            88  230c4e4d-70c3-461d-b42c-ec09396efb3f
#
#                               User ID_x     Type             Datetime  \
# 0  5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 1  34e8add9-0206-47fd-a501-037b994650a2  disgust  2021-01-06 19:13:01
# 2  13c06e7e-833d-47eb-a790-5e09ccfd8d2c  disgust  2021-04-09 02:46:20
# 3  8b49caad-bcc5-43de-bf40-34a66ff8805c  disgust  2021-03-28 21:15:26
# 4  ef147ea5-9696-44d5-b6c2-a43f62fd8ce2  disgust  2020-08-04 05:40:33
#
#    Unnamed: 0_y                             User ID_y Content_Type  \
# 0             0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo
# 1             0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31        photo
# ...

# %%
final_df.drop(['URL','User ID_x','User ID_y'], axis=1,inplace=True)

# %%
final_df
# Out:
#        Unnamed: 0_x                            Content ID     Type  \
# 0                 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust
# 1                 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust
# 2                35  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust
# 3                52  9f737e0a-3cdd-4d29-9d24-753f4e3be810  disgust
# 4                88  230c4e4d-70c3-461d-b42c-ec09396efb3f  disgust
# ...             ...                                   ...      ...
# 24568         25489  435007a5-6261-4d8b-b0a4-55fdc189754b    adore
# 24569         25491  435007a5-6261-4d8b-b0a4-55fdc189754b    adore
# 24570         25512  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore
# 24571         25524  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore
# 24572         25531  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore
#
#                   Datetime  Unnamed: 0_y Content_Type        Category  \
# 0      2020-11-07 09:43:50             0        photo        Studying
# ...

# %%
# @title Content_Type

from matplotlib import pyplot as plt
import seaborn as sns
final_df.groupby('Content_Type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# import the dataframe back to excel

# %% [markdown]
# Top 5 Categories

# %%
Top5_Categories = Top5_caps.value_counts().head(5)

# %%
Top5_Categories
# Out:
# Animals           1897
# Science           1796
# Healthy eating    1717
# Food              1699
# Technology        1698
# Name: Category, dtype: int64

# %%
final_df['Category'] = final_df['Category'].str.strip('"')

# %%
Top5_caps =final_df["Category"].str.capitalize()

# %%
with pd.ExcelWriter('output.xlsx') as writer:
    final_df.to_excel(writer, sheet_name='Final_Dataset')
    Top5_Categories.to_excel(writer, sheet_name='Top 5 Categories')

# %% [markdown]
# Plot of the 5 top categeries

# %%
Top5_Categories = Top5_caps.value_counts().head(5).plot(kind='bar',color =sns.palettes.mpl_palette("Dark2"),title='Top 5 Categories')

# %%
Top5_Categories = Top5_caps.value_counts().head(5).plot(kind='pie',title='Top 5 Categories',autopct='%1.0f%%')

# %% [markdown]
# How many unique categories are there

# %%
unique_Categories = Top5_caps.value_counts()

# %%
unique_Categories
# Out:
# Animals            1897
# Science            1796
# Healthy eating     1717
# Food               1699
# Technology         1698
# Culture            1676
# Cooking            1664
# Travel             1647
# Soccer             1457
# Education          1433
# Fitness            1395
# Studying           1363
# Dogs               1338
# Tennis             1328
# Veganism           1248
# Public speaking    1217
# Name: Category, dtype: int64

# %%
unique_Categories=Top5_caps.value_counts().plot(kind='bar',orientation='vertical',title='Count of Unique Categories',color=['purple','yellow'])

# %% [markdown]
# What was the month with the most posts

# %%
final_df.dtypes
# Out:
# Unnamed: 0_x     int64
# Content ID      object
# Type            object
# Datetime        object
# Unnamed: 0_y     int64
# Content_Type    object
# Category        object
# Unnamed: 0       int64
# Sentiment       object
# Score            int64
# dtype: object

# %%
final_df['date'] = pd.to_datetime(final_df['Datetime'])

# %%
final_df
# Out:
#        Unnamed: 0_x                            Content ID     Type  \
# 0                 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust
# 1                 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust
# 2                35  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust
# 3                52  9f737e0a-3cdd-4d29-9d24-753f4e3be810  disgust
# 4                88  230c4e4d-70c3-461d-b42c-ec09396efb3f  disgust
# ...             ...                                   ...      ...
# 24568         25489  435007a5-6261-4d8b-b0a4-55fdc189754b    adore
# 24569         25491  435007a5-6261-4d8b-b0a4-55fdc189754b    adore
# 24570         25512  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore
# 24571         25524  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore
# 24572         25531  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore
#
#                   Datetime  Unnamed: 0_y Content_Type        Category  \
# 0      2020-11-07 09:43:50             0        photo        Studying
# ...

# %%
final_df['month'] = final_df['date'].dt.month

# %%
final_df
# Out:
#        Unnamed: 0_x                            Content ID     Type  \
# 0                 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust
# 1                 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust
# 2                35  97522e57-d9ab-4bd6-97bf-c24d952602d2  disgust
# 3                52  9f737e0a-3cdd-4d29-9d24-753f4e3be810  disgust
# 4                88  230c4e4d-70c3-461d-b42c-ec09396efb3f  disgust
# ...             ...                                   ...      ...
# 24568         25489  435007a5-6261-4d8b-b0a4-55fdc189754b    adore
# 24569         25491  435007a5-6261-4d8b-b0a4-55fdc189754b    adore
# 24570         25512  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore
# 24571         25524  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore
# 24572         25531  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    adore
#
#                   Datetime  Unnamed: 0_y Content_Type        Category  \
# 0      2020-11-07 09:43:50             0        photo        Studying
# ...

# %%
final_df.groupby('month')['Content ID'].count().sort_values(ascending= False)
# Out:
# month
# 5     2138
# 1     2126
# 8     2114
# 12    2092
# 7     2070
# 10    2056
# 11    2034
# 9     2022
# 6     2021
# 3     2012
# 4     1974
# 2     1914
# Name: Content ID, dtype: int64

# %%
from pickle import FALSE
month_highest=final_df.groupby('month')['Content ID'].count().plot(kind='bar',title='Month with the highest Content',color='blue').sort_ascending=FALSE

# %% [markdown]
# How many reactions are there to the most popular category?

# %%
final_df.groupby('Category')['Sentiment'].count().sort_values(ascending=False).plot(title="Reactions in the Most popular Category", color='blue')
# Out:
# <Axes: title={'center': 'Reactions in the Most popular Category'}, xlabel='Category'>
